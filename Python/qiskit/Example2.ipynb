# %% [markdown]
# # Qiskit Example 2
#
# This Notebook is a more detailed example of using Qiskit.
#
# The aim is to produce the Bell state:
# $
# \psi = \dfrac{(|000 \rangle + |111 \rangle)}{\sqrt{2}}
# $
#
# It is a simplified example of the Circuits Basics Tutorial in the [qiskit documentation](https://github.com/Qiskit/qiskit-tutorials/blob/master/tutorials/circuits/01_circuit_basics.ipynb) which is part of Qiskit and is copyright of IBM 2017, 2021.
#
# This code is licensed under the Apache License, Version 2.0. You may obtain a copy of this license in the LICENSE.txt file in the root directory of the original Notebooks source tree or at http://www.apache.org/licenses/LICENSE-2.0.
#
# Any modifications or derivative works of the orginal code must retain this copyright notice, and modified files need to carry a notice indicating that they have been altered from the originals.

# %% [markdown]
# ## Step 1 : Import Packages

# %%
import numpy as np
from qiskit import QuantumCircuit, transpile
from qiskit.providers.aer import QasmSimulator
from qiskit.visualization import plot_histogram

# %% [markdown]
# ## Step 2 : Initialize Variables

# %%
#Initialize three qubits and three classical bits 
# circ = 
circ = QuantumCircuit(3, 3)

# %% [markdown]
# ## Step 3 : Add Gates
# Construct a Bell state by setting up a Hadamard and a CX gate and measure the result.

# %%
# Add a H gate on qubit 0, putting this qubit in superposition.
circ.h(0)
# Add a CX (CNOT) gate on control qubit 0 and target qubit 1, putting
# the qubits in a Bell state.
circ.cx(0, 1)
# Add a CX (CNOT) gate on control qubit 0 and target qubit 2, putting
# the qubits in a GHZ state.
circ.cx(0, 2)
#add code to measure the results.
circ.measure([0,1,2], [0,1,2])

# %% [markdown]
# ## Step 4 : Visualize the Circuit
# View the circuit that you have built.

# %%
# Note that by using mpl we can get a better picture
circ.draw('mpl')

# %% [markdown]
# ## Step 5 : Simulate the Experiment
# Simulate the circuit and print out the results.

# %%
simulator = QasmSimulator()
compiled_circuit = transpile(circ, simulator)
job = simulator.run(compiled_circuit, shots=1000)
result = job.result()
counts = result.get_counts(circ)
# add some code to print out the results
print("\nTotal count for 000 and 111 are:",counts)
# Out:
# Total count for 000 and 111 are: {'000': 525, '111': 475}

# %% [markdown]
# ## Step 6 : Visualize the Results
# Plot a histogram to visualise the results

# %%
#add code to plot a histogram of the results
plot_histogram(counts)
